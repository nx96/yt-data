# %%
# %load_ext autoreload
# %autoreload 2

from src.channel import USERNAME
from src.data import add_column_show, generate_csv, generate_excel_by_csv
from src.graphs import plot_text, plot_show_by_view_count, plot_show_by_like_count, plot_show_by_comment_count, plot_longest_video

# %% [markdown]
# Generar CSV con datos del canal

# %%
df = generate_csv(USERNAME)
# Out:
# File created at ./outputs/data_SUERTE-TV.csv

# %% [markdown]
# Agregar columna 'Show'
# Para identificar cada video

# %%
df = add_column_show(USERNAME)

# %% [markdown]
# Crear archivo Excel

# %%
generate_excel_by_csv(USERNAME)
# Out:
# File created at ./outputs/data_SUERTE-TV.xlsx

# %% [markdown]
# ## Análisis - Canal SuerteTV
# Autor: Nixon Quezada
#
# Contacto: nxquezada19@gmail.com
#
# Corte: 04/12/2024
# ### Contador suscriptores y vistas

# %%
plot_text(df)

# %% [markdown]
# ## Video más largo

# %%
plot_longest_video(df)

# %% [markdown]
# ### Video más reproducido por programa

# %%
plot_show_by_view_count(df)
# Out:
# Otros =>	 SorbiSomos - Una preli con Luisito Comunica 🫡🔝
# El Remember! =>	 El Remember!😎 - Ex 29 - Nos acalambramos bailando marroneo 😮‍💨
# Hueveando =>	 Hueveando: No me dieron visa por p3nd3j0 🗽
# #SIEMPRELOMISMO =>	 #SIEMPRELOMISMO - HOY NOS DESCOCAMOS 🛑 🥥
# Sí Somos =>	 Si Somos - Una fiesta nos costó el departamento 🥲
# Sorbito de Opinión =>	 Sorbito de Opinión - Ahhhhhh entonces tú mamá compró el reloj ⌚️

# %% [markdown]
# ### Video con más likes por programa

# %%
plot_show_by_like_count(df)
# Out:
# Otros =>	 SorbiSomos - Una preli con Luisito Comunica 🫡🔝
# El Remember! =>	 El Remember! 😎 - El primer beso de Alex fue con… 👀🤫
# Hueveando =>	 Hueveando: No me dieron visa por p3nd3j0 🗽
# #SIEMPRELOMISMO =>	 #SIEMPRELOMISMO - HOY NOS DESCOCAMOS 🛑 🥥
# Sí Somos =>	 Si Somos - Qué es peor: un ex o un casi algo.
# Sorbito de Opinión =>	 Sorbito de Opinión - Este premio no me lo quita nadie! 🏆😡

# %% [markdown]
# ### Video con más comentarios por programa

# %%
plot_show_by_comment_count(df)
# Out:
# Otros =>	 SorbiSomos - Una preli con Luisito Comunica 🫡🔝
# El Remember! =>	 El Remember! 😎 - El primer beso de Alex fue con… 👀🤫
# Hueveando =>	 Hueveando: No me dieron visa por p3nd3j0 🗽
# #SIEMPRELOMISMO =>	 #SIEMPRELOMISMO - HOY NOS DESCOCAMOS 🛑 🥥
# Sí Somos =>	 Si Somos - Volví para quedarme 😎
# Sorbito de Opinión =>	 Sorbito de Opinión - Un regreso un poco diferente 👀
