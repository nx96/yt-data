# %%
# %load_ext autoreload
# %autoreload 2

from src.channel import USERNAME
from src.data import add_columns_to_df, generate_csv, generate_excel_by_csv
from src.graphs import *

# %% [markdown]
# Generar CSV con datos del canal

# %%
df = generate_csv(USERNAME)
# Out:
# File created at ./outputs/data_SUERTE-TV.csv

# %% [markdown]
# Agregar columna 'Show'
# Para identificar cada video

# %%
df = add_columns_to_df(USERNAME)

# %% [markdown]
# Crear archivo Excel

# %%
generate_excel_by_csv(USERNAME)
# Out:
# File created at ./outputs/data_SUERTE-TV.xlsx

# %% [markdown]
# ## Análisis - Canal SuerteTV
# Autor: Nixon Quezada
#
# Contacto: nxquezada19@gmail.com
#
# Corte: 15/12/2024
#
# NOTA: La categoría **"Otros"** es la unión de: Sorbisomos, Recap, pilotos, episodios especiales, shorts, etc.
# ### Contador suscriptores y vistas

# %%
plot_text(df)

# %% [markdown]
# ## Video más largo

# %%
plot_longest_video(df)

# %% [markdown]
# ### Video más reproducido por programa

# %%
plot_show_by_view_count(df)

# %% [markdown]
# ### Video con más likes por programa

# %%
plot_show_by_like_count(df)

# %% [markdown]
# ### Video con más comentarios por programa

# %%
plot_show_by_comment_count(df)

# %% [markdown]
# ## Promedio duración - Sorbito de Opinión

# %%
plot_evolution_by_duration(df=df, program='Sorbito de Opinión')

# %% [markdown]
# ## Promedio duración - Sí Somos

# %%
plot_evolution_by_duration(df=df, program='Sí Somos')

# %% [markdown]
# ## Total de videos por programa

# %%
plot_chapters_by_show(df)

# %% [markdown]
# ## Total de duración de videos por programa

# %%
plot_duration_by_show(df)
