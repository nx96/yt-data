# %%
# %load_ext autoreload
# %autoreload 2

from src.channel import USERNAME
from src.data import add_column_show, generate_csv, generate_excel_by_csv
from src.graphs import plot_text, plot_show
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Generar CSV con datos del canal

# %%
df = generate_csv(USERNAME)
# Out:
# File created at ./outputs/data_SUERTE-TV.csv

# %% [markdown]
# Agregar columna 'Show'
# Para identificar cada video

# %%
df = add_column_show(USERNAME)

# %% [markdown]
# Crear archivo Excel

# %%
generate_excel_by_csv(USERNAME)
# Out:
# File created at ./outputs/data_SUERTE-TV.xlsx

# %% [markdown]
# Total de suscripciones y vistas

# %%
plot_text(df)

# %% [markdown]
# El programa más visto por Show

# %%
plot_show(df)
# Out:
# Otros =>	 SorbiSomos - Una preli con Luisito Comunica 🫡🔝 (418687 vistas)
# El Remember! =>	 El Remember!😎 - Ex 29 - Nos acalambramos bailando marroneo 😮‍💨 (218170 vistas)
# Hueveando =>	 Hueveando: No me dieron visa por p3nd3j0 🗽 (94797 vistas)
# #SIEMPRELOMISMO =>	 #SIEMPRELOMISMO - HOY NOS DESCOCAMOS 🛑 🥥 (40060 vistas)
# Sí Somos =>	 Si Somos - Una fiesta nos costó el departamento 🥲 (423538 vistas)
# Sorbito de Opinión =>	 Sorbito de Opinión - Ahhhhhh entonces tú mamá compró el reloj ⌚️ (809894 vistas)
